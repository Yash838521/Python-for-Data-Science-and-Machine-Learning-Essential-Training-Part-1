# %% [markdown]
# Streamlit:
# 1.supports all of the main python plotting libraries, including matplotlib, seaborn, plotly etc.
# 2.open source
# 3.it runs on it's own server and it doesn't support jupyter notebook.
# 4.Can easily be deployed and supports almost all the deployment platforms
#
# Panel:
# 1. it is another python library, that lets you create custom, interactive web apps and dashboards, by connecting user-defined widgets to plots, images, tables or text
#
# Voila:
# 1.Voila is a tool that lets you turn any jupyter notebook into a standalone web application
# 2. It allows you to create interactive webpages and iit has great support for widgets, such as IPyWidgets
# 3. It supports multipl languages: Python, c++, Julia
# 4.incredabely easy to create interactive dashboards but it has limited design flexibility but it does  give the option to create your own template
# 5.It has exceptional support for jupyter notebooks
# 6. can eaily be deployed and supports almost all deployment platforms
#
# Dash:
# 1.Dash is a Web application development framework from Ployly, it is build specifically for developing data applications
# 2.dash offers users a very easy way of developing dynamic dashboards.
# 3.supports language like python, R, Julia
# 4. Primarily built for use with the python library plotly
# 5. it explicitly supports multi-page web application

# %%
import streamlit as st

# %%
st.write('hello world')
# Out:
# 2026-02-17 16:56:48.818 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-17 16:56:49.053
# ...
#   command:
#
#     streamlit run c:\Users\HP\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-02-17 16:56:49.054 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-17 16:56:49.055 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
