# %% [markdown]
# #Data visualization is important because data #insights cannot be converted to business value if #they are not communicated effectively.
# #Data visulazation is is from if chart or graphs, find valuable inslights.

# %%
#three types of data visulazition
#1.Data Storytelling- for presentations to organizational decision- makers
#2. Data showcasing- for presentations to analysts, scientists,mathematicians and engineers
#Data art- for presentations to activites or the general public

# %%
#2. data showcasing
Your data visulazition should be:
highly contextual
open-ended

Intended audience:
Analysts, quants
engineers, mathematicians, scientists

Product types:
interactive dasboards

# %%
Four steps to choosinf Data Graphics:
1. Make a list of the questions that your data visulazition is ment to answer
2. Is your data visualization type data Storytelling, data showcasing, data art?
3. what data graphic types are preferable for that type of data visualization?
4. Test out different types of data graphic with your data. Which graphic type displays the clearest and most obvius answer to your questions?
